# %% [markdown]
# # Module 8 — Virtual Environments & Packaging
#
# This module teaches how to manage project dependencies with virtual environments and how to package Python code for reuse.

# %% [markdown]
# ## Learning Objectives
#
# - Create and activate virtual environments
# - Install and manage packages with `pip`
# - Use `requirements.txt`
# - Understand package layout and `pyproject.toml` basics

# %% [markdown]
# ## Virtual environments
#
# A virtual environment isolates dependencies per project. Create one with `python -m venv .venv`.

# %%
# Example terminal commands (do not run in notebook):
# python -m venv .venv
# .venv\Scripts\activate  # Windows
# source .venv/bin/activate  # macOS/Linux

# %% [markdown]
# ## Installing packages
#
# Use `pip install` inside the activated environment to add packages. Use `pip freeze > requirements.txt` to pin versions.

# %%
# Example terminal commands (do not run here):
# pip install requests pandas
# pip freeze > requirements.txt

# %% [markdown]
# ## Project packaging
#
# A Python package is a directory with `__init__.py`. You can also use `pyproject.toml` to define package metadata.

# %%
# Example package structure:
# mypackage/
#   __init__.py
#   utils.py
# pyproject.toml

# %% [markdown]
# ## Writing `requirements.txt`
#
# List project dependencies one per line. Example below.

# %%
requirements = [
    'jupyterlab',
    'pytest',
    'pandas',
    'requests',
    'beautifulsoup4',
]
print('
'.join(requirements))

# %% [markdown]
# ## Exercise 1 — Create a virtual environment
#
# Practice the commands for your platform and verify `python --version` inside the env.

# %% [markdown]
# ## Exercise 2 — Make a package
#
# Create a folder `mytools` with `__init__.py` and one helper file. Import it from a script.

# %% [markdown]
# ## Mini-Project — Package a helper library
#
# Create a package called `course_utils` with a function to format textbook-style output and import it in another script. Use a `requirements.txt` file to pin dependencies.

# %% [markdown]
# ## Summary
#
# Module 8 explains how to isolate dependencies and structure Python projects for reuse and sharing.
